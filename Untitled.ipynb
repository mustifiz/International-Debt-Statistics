# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df =pd.read_csv ('IDS-DRSCountries_WLD_Country-SeriesMetadata.csv')
da =pd.read_csv('IDS-DRSCountries_WLD_CountryMetadata.csv')
db =pd.read_csv('IDS-DRSCountries_WLD_Data.csv')
dc =pd.read_csv('IDS-DRSCountries_WLD_Footnotes.csv')
dg =pd.read_csv('IDS-DRSCountries_WLD_SeriesMetadata.csv')

# %%
df.head()
# Out:
#              Type       Country Code  \
# 0  Country-Series  Afghanistan (AFG)
# 1  Country-Series  Afghanistan (AFG)
# 2  Country-Series       Angola (AGO)
# 3  Country-Series       Angola (AGO)
# 4  Country-Series      Albania (ALB)
#
#                                          Series Code  \
# 0  Foreign direct investment, net inflows in repo...
# 1  External debt stocks, total (DOD, current US$)...
# 2  Foreign direct investment, net inflows in repo...
# 3  External debt stocks, total (DOD, current US$)...
# 4  Foreign direct investment, net inflows in repo...
#
#                                          Description
# 0  Data on Foreign Direct Investment are based on...
# 1  Long-term public and publicly guaranteed and l...
# 2  Data on Foreign Direct Investment are based on...
# 3  Long-term public and publicly guaranteed debt ...
# 4  Data on Foreign Direct Investment are based on...

# %%
da.isnull().sum()
# Out:
# Code                                                   0
# Long Name                                              0
# Income Group                                          13
# Region                                                13
# Lending category                                      13
# Other groups                                          93
# Currency Unit                                         13
# Latest population census                              15
# Latest household survey                               16
# Special Notes                                         94
# National accounts base year                           13
# National accounts reference year                     103
# System of National Accounts                           14
# SNA price valuation                                   13
# Alternative conversion factor                         93
# PPP survey years                                      14
# ...

# %%
db
# Out:
#                                             Country Name Country Code  \
# 0                                            Afghanistan          AFG
# 1                                            Afghanistan          AFG
# 2                                            Afghanistan          AFG
# 3                                            Afghanistan          AFG
# 4                                            Afghanistan          AFG
# ...                                                  ...          ...
# 66101                                                NaN          NaN
# 66102                                                NaN          NaN
# 66103                                                NaN          NaN
# 66104  Data from database: International Debt Statistics          NaN
# 66105                           Last Updated: 10/16/2020          NaN
#
#       Counterpart-Area Name Counterpart-Area Code  \
# 0                     World                   WLD
# ...

# %%
db.isnull().sum()
# Out:
# Country Name                 3
# Country Code                 5
# Counterpart-Area Name        5
# Counterpart-Area Code        5
# Series Name                  5
#                          ...
# 2023                     54492
# 2024                     54659
# 2025                     54939
# 2026                     55129
# 2027                     55272
# Length: 64, dtype: int64

# %%
dc['Country Code'].isnull().sum()
# Out:
# 0

# %%
dg.head()
# Out:
#           Code License Type  \
# 0  DT.GPA.DPPG          NaN
# 1  DT.GPA.OFFT          NaN
# 2  DT.GPA.PRVT          NaN
# 3  DT.GRE.DPPG          NaN
# 4  DT.GRE.OFFT          NaN
#
#                                       Indicator Name  \
# 0  Average grace period on new external debt comm...
# 1  Average grace period on new external debt comm...
# 2  Average grace period on new external debt comm...
# 3  Average grant element on new external debt com...
# 4  Average grant element on new external debt com...
#
#                                     Short definition  \
# 0  Grace period is the period from the date of si...
# 1  Grace period is the period from the date of si...
# 2  Grace period is the period from the date of si...
# 3  The grant element of a loan is the grant equiv...
# 4  The grant element of a loan is the grant equiv...
#
#                                      Long definition  \
# 0  Grace period is the period from the date of si...
# ...
